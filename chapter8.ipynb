# %% [markdown]
# <a href="https://colab.research.google.com/github/ctk03272/deeplearningstudy/blob/main/chapter8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![스크린샷 2024-05-21 오전 2.48.58.png](data:image/png;base64,...)

# %% [markdown]
# ## 8.1 더 깊게
# - 이번장에서 만들 신경망은 위의 사진과 같다.
# - 여기에서 사용하는 합성곱 계층은 층이 깊어지면서 채널 수가 더 늘어나는 특징이 있다.
# - 가중치 초기값은 He 초기값, 매개변수 갱신에는 Adam 사용
# - 이 신경망의 결과로 인식하지 못한 경우에는 인간도 판단하기 힘든 이미지들....
#
# ## 8.1.2 정확도를 높이려면
# - what is the class of this image? 사이트를 참고하면 정확도 높은 코드들을 확인 가능
# - 데이터 확장은 손쉬우면서 정확도 개선에 효과적
#   - 입력 이미지를 알고리즘을 동원해 인위적으로 확장
#   - 잘라내거나 뒤집거나 회전하거나 등등
#
# ## 8.1.3 깊게 하는 이유
# - 층을 깊게 하는 것의 중요성?
#   실제 대회에서 상위권은 신경망을 더 깊게 가능 방향성....? 근데 이건 이유가 맞나..? 그냥 결과 같은데...
# - 층을 깊게 한 신경망은 깊지 않은 경우보다 적은 매개변수로 같거나 더 좋은 표현력 달성 가능
# - 층을 깊게 함으로써 각 층이 학습해야 할 문제를 '풀기 쉬운 단순한 문제'로 분해 할 수 있어 효율적으로 학습하리라 기대할 수 있다.
#
# # 8.2 딥러닝의 초기 역사
# ## 8.2.1 이미지넥
# - 100만장이 넘는 이미지를 담고 있는 데이터셋.
# - 2012년 이후 선두는 항상 딜버닝
#
# ## 8.2.2 VCG
# - 3*3의 작은 필터를 사용한 합성곱 계층을 연속으로 거친다.
#
# ## 8.2.3 GoogLeNet
# - 가로 방향에 폭이 있다. 이를 인셉션 구조라고 한다.
# - 크기가 다른 필터를 여러개 적용
#
# ## 8.2.4 ResNet
# - 스킵 연결을 통해 층의 깊이에 비례해 성능을 향상
# - 역전파 때 스킵 연결이 신호 감쇠를 막아준다.
#
# ## 8.3 더 빠르게(딥러닝 고속화)
# ### 8.3.1 풀어야 할 숙제
# - 오랜 시간을 합성곱 계층에서 소요
#
# ### 8.3.2 GPU를 활용한 고속화
# - 병렬 수치 연산을 고속으로 처리 가능
# - 대부분 딥러닝 프레임워크는 CUDA를 사용
#
# ### 8.3.3 분산 학습
# - 딥러닝은 그래도 오래걸림, 그래서 딥러닝 학습을 수평 확장 하자는 아이디어가 중요함
# - 구글의 텐서플로우와 마이크로소프트이 CNTK는 분산 학습에 역점
#
# ### 8.3.4 연산 정밀도와 비트 줄이기
# - 딥러닝은 16비트 반정밀도만 사용해도 학습에 문제가 없음...
#
# ## 8.4 딥러닝의 활용
# ### 8.4.1 사물 검출
# - 지금까지의 사물인식은 이미지 전체를 대상으로 했는데, 사물 검출은 어딘가에 있을 사물위 위치도 알아내야 해서 어려움
# - R-CNN이 유명함
#
# ### 8.3.2 분할
# - FCN 기법이 고안
#
# ### 8.4.3 사진 캡션 생성
# - 사진을 설명하는 글을 자동으로 생성
# - NIC 모델이 대표적
